# %% [markdown]
# <h2>Part 1</h2>
# <p>Reading data</p>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('data/survey_results_public.csv')
df_schema = pd.read_csv("data/survey_results_schema.csv")

# %%
pd.set_option("display.max_columns", 48)
pd.set_option("display.max_rows", 48)

# %%
df.head(3)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
#
#                                           Employment             Country  \
# 0  Independent contractor, freelancer, or self-em...            Slovakia
# 1                                 Student, full-time         Netherlands
# 2                                 Student, full-time  Russian Federation
#
#   US_State UK_Country                                            EdLevel  \
# 0      NaN        NaN  Secondary school (e.g. American high school, G...
# 1      NaN        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2      NaN        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#       Age1stCode                                          LearnCode YearsCode  \
# ...

# %%
df_schema
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %% [markdown]
# <h2>Part 2</h2>
# <p>Dataframes and series</p>

# %%
# To convert dectionary to DataFrame use function
# df = pd.DataFrame(dictionary)

# %%
# creating a subframe using slicing
# loc - location. Slicing can be used, slicing is inclusive and works with labels
df.loc[5:25:5, 'SOComm':'Accessibility']
# subframe, columns are rows should be specified as to lists
df.loc[[5, 10, 15, 20, 25], ['SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality', 'Ethnicity', 'Accessibility']]

# the same output, iloc (index location) uses indexing. However, slicing here is exclusive
subdf = df.iloc[5:26:5, 36:44]

# %%
# FataFrame type
# two-dimensional data structure
type(subdf)
# Out:
# pandas.core.frame.DataFrame

# %%
# check existing columns
print(subdf.columns)
# Out:
# Index(['SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility'],
#       dtype='object')

# %%
# Series 
# one-dimentional array
series1 = df['SOComm']
series2 = df.loc[1]

print(series1[:5], '\n----------------\n', series2[:5])
# Out:
# 0    Yes, definitely
# 1    Yes, definitely
# 2    Yes, definitely
# 3            Neutral
# 4      Yes, somewhat
# Name: SOComm, dtype: object
# ----------------
#  ResponseId                                         2
# MainBranch    I am a student who is learning to code
# Employment                        Student, full-time
# Country                                  Netherlands
# US_State                                         NaN
# Name: 1, dtype: object

# %%
# get some statistics from Series
series1.value_counts()
# Out:
# Yes, somewhat      23584
# No, not really     20697
# Neutral            17084
# Yes, definitely    12888
# No, not at all      6633
# Not sure            1433
# Name: SOComm, dtype: int64

# %%
# Series type
print(type(series1))
print(type(series2))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# <h2>Indexes</h2>
# <p>Index is a unique idenfitier of the row</p>

# %%
# setting new index col, however, it erases previous index col
df.set_index('Employment', inplace=True)

# after setting index, you can refer to it using loc method
# index column should not be unique
df.loc["Student, full-time"]

# resetting index column, previous index column becomes the first column in DataFrame
df.reset_index(inplace=True)
df.head(3)
# Out:
#                                           Employment  ResponseId  \
# 0  Independent contractor, freelancer, or self-em...           1
# 1                                 Student, full-time           2
# 2                                 Student, full-time           3
#
#                                           MainBranch             Country  \
# 0                     I am a developer by profession            Slovakia
# 1             I am a student who is learning to code         Netherlands
# 2  I am not primarily a developer, but I write co...  Russian Federation
#
#   US_State UK_Country                                            EdLevel  \
# 0      NaN        NaN  Secondary school (e.g. American high school, G...
# 1      NaN        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2      NaN        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#       Age1stCode                                          LearnCode YearsCode  \
# ...

# %%
# setting ResponseId column as an index column 
df = pd.read_csv("data/survey_results_public.csv", index_col='ResponseId')
df.head(3)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
#
#                        Country US_State UK_Country  \
# ResponseId
# 1                     Slovakia      NaN        NaN
# 2                  Netherlands      NaN        NaN
# 3           Russian Federation      NaN        NaN
#
#                                                       EdLevel     Age1stCode  \
# ResponseId
# 1           Secondary school (e.g. American high school, G...  18 - 24 years
# ...

# %%
df_schema.set_index('qname', inplace=True)
df_schema.head(5)
# Out:
#               qid                                           question  \
# qname
# S0          QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo    QID12                                  Browser Meta Info
# S1           QID1  <span style="font-size:22px; font-family: aria...
# MainBranch   QID2  Which of the following options best describes ...
# Employment  QID24  Which of the following best describes your cur...
#
#             force_resp  type selector
# qname
# S0               False    DB       TB
# MetaInfo         False  Meta  Browser
# S1               False    DB       TB
# MainBranch        True    MC     SAVR
# Employment       False    MC     MAVR

# %%
# now we can read unclear question by quesiton name index
df_schema.loc['SOComm', 'question']
# Out:
# 'Do you consider yourself a member of the Stack Overflow community?'

# %%
# we can also sort our DataFrames
df_schema.sort_index(inplace=True)
df_schema.head(5)
# Out:
#                   qid                                           question  \
# qname
# Accessibility  QID124  Which of the following describe you, if any? P...
# Age            QID127                                  What is your age?
# Age1stCode     QID149  At what age did you write your first line of c...
# CompFreq        QID52   Is that compensation weekly, monthly, or yearly?
# CompTotal       QID51  What is your current total compensation (salar...
#
#                force_resp type selector
# qname
# Accessibility       False   MC     MAVR
# Age                 False   MC     MAVR
# Age1stCode          False   MC     MAVR
# CompFreq            False   MC     MAVR
# CompTotal           False   TE       SL

# %% [markdown]
# <h2>Filtering</h2>

# %%
# in order to filter we should create filt variable first. It should be a Series object that contains True and Flase fields 
filt_py = (df['LanguageHaveWorkedWith'].str.contains('Python', na=False)) & ~(df['ConvertedCompYearly'].isnull()) &\
          (df['Age'] != "Prefer not to say")
filt = ~(df['ConvertedCompYearly'].isnull()) & (df['Age'] != "Prefer not to say")
type(filt)
# Out:
# pandas.core.series.Series

# %%
# we can use this object with loc method.
df_python = df.loc[filt_py]
df_python.head(5)
# Out:
#                                                    MainBranch  \
# ResponseId
# 10                             I am a developer by profession
# 19          I am not primarily a developer, but I write co...
# 24                             I am a developer by profession
# 27          I am not primarily a developer, but I write co...
# 28                             I am a developer by profession
#
#                      Employment  \
# ResponseId
# 10           Employed full-time
# 19          I prefer not to say
# 24           Employed full-time
# 27           Employed full-time
# 28           Employed full-time
#
#                                                       Country US_State  \
# ResponseId
# 10                                                     Sweden      NaN
# 19                                                  Singapore      NaN
# 24                                                     France      NaN
# ...

# %%
# we also can choose some columns in addition to filtered rows
df_python = df.loc[filt_py, ['Age', 'ConvertedCompYearly']]
df_all = df.loc[filt, ['Age', 'ConvertedCompYearly']]
print(df_python.head(10))
# Out:
#                         Age  ConvertedCompYearly
# ResponseId
# 10          25-34 years old              51552.0
# 19          45-54 years old             160932.0
# 24          25-34 years old              38915.0
# 27          25-34 years old              81319.0
# 28          45-54 years old              68507.0
# 32          25-34 years old             122580.0
# 36          25-34 years old              60535.0
# 42          25-34 years old              25944.0
# 56          35-44 years old              64630.0
# 59          25-34 years old              22644.0

# %%
df_python['Age'].value_counts()
# Out:
# 25-34 years old       9976
# 35-44 years old       4140
# 18-24 years old       3914
# 45-54 years old       1303
# 55-64 years old        390
# 65 years or older       56
# Under 18 years old      52
# Name: Age, dtype: int64

# %%
# function returns average salary of developer in a given DataFrame by given Age string
def get_average_salary_by_age(df, s):
    lst = list(df.loc[(df['Age'] == s), 'ConvertedCompYearly'])
    return sum(lst)/len(lst)

# %%
ax_indices = pd.Series(["Under 18 years old", "18-24 years old", "25-34 years old", "35-44 years old", "45-54 years old",
              "55-64 years old", "65 years or older"])
y_python = pd.Series([get_average_salary_by_age(df_python, s) for s in ax_indices])
y_all = pd.Series([get_average_salary_by_age(df_all, s) for s in ax_indices])

# %%
fig, ax = plt.subplots()

ax.fill_between(ax_indices, y_python, y2=y_all, where=(pd.Series(y_python) > pd.Series(y_all)) ,color='#ACD1AF', 
                interpolate=True, alpha=0.5, label='Python devs earn more')
ax.fill_between(ax_indices, y_python, y2=y_all, where=(pd.Series(y_python) < pd.Series(y_all)) ,color='#F47174', 
                interpolate=True, alpha=0.5, label='Python devs earn less')

ax.plot_date(ax_indices, y_python, linestyle='solid', label='Python Developers')
ax.plot_date(ax_indices, y_all, linestyle='solid', label='All Developers')

fig.autofmt_xdate()

ax.set_ylabel('Salary')
ax.set_title('Average Developers Salary by Age')
ax.legend(loc="lower right")

fig.savefig('AverageDevSalaryByAge(line).png')

fig.tight_layout()

plt.show()

# %%
width = 0.3

fig, ax = plt.subplots()

ax.fill_between(ax_indices, y_python, where=(pd.Series(y_python) > pd.Series(y_all)) ,color='#ACD1AF', 
                interpolate=True, alpha=0.2, label='Python devs earn more')
ax.fill_between(ax_indices, y_all, where=(pd.Series(y_python) < pd.Series(y_all)) ,color='#F47174', 
                interpolate=True, alpha=0.2, label='Python devs earn less')

barx = np.arange(len(ax_indices))

ax.bar(barx-width/2, y_python, width=width, label='Python Developers')
ax.bar(barx+width/2, y_all, width=width, label='All Developers')

ax.set_xticks(barx, labels=ax_indices)

fig.autofmt_xdate()

ax.set_ylabel('Salary')
ax.set_title('Average Developers Salary by Age')
ax.legend(loc="upper left")

fig.savefig('AverageDevSalaryByAge(Bar).png')

fig.tight_layout()

plt.show()
